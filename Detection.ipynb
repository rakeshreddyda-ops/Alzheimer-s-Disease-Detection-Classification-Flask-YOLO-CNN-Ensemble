# %% [markdown]
# # Importing the Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"

# %%
import torch
from IPython.display import Image
import shutil
import os
from random import choice

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
ML_Model = []
precision = []
recall = []
mAP = []

#function to call for storing the results
def storeResults(model, a,b,c):
    ML_Model.append(model)
    precision.append(round(a, 3))
    recall.append(round(b, 3))
    mAP.append(round(c, 3))

# %%
# !mkdir v5

# %%
cd v5
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/v5

# %% [markdown]
# # **YoloV5s**

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5s6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/yolov5/data.yaml", epochs=50, imgsz=416)  # train the
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 29.6M/29.6M [00:00<00:00, 60.3MB/s]
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
p_yol5 = 0.882
r_yol5 = 0.829
mAP_yolo5 = 0.924

storeResults('Yolo v5s6',p_yol5,r_yol5,mAP_yolo5)

# %%
# dislaying metrics for train data
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train/F1_curve.png')
y = Image(filename='runs/detect/train/PR_curve.png')
z = Image(filename='runs/detect/train/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # **Yolov5x6**

# %%
from ultralytics import YOLO
# Load a model

# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov5x6u.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/yolov5/data.yaml", epochs=50, imgsz=416)  # train the
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 297M/297M [00:05<00:00, 61.7MB/s]
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
p_yol5 = 0.856
r_yol5 = 0.819
mAP_yolo5 = 0.918

storeResults('Yolo v5x6',p_yol5,r_yol5,mAP_yolo5)

# %%
x = Image(filename='runs/detect/train2/F1_curve.png')
y = Image(filename='runs/detect/train2/PR_curve.png')
z = Image(filename='runs/detect/train2/confusion_matrix.png')
display(x, y,z)

# %% [markdown]
# # YoloV8

# %%
cd /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3

# %%
# !mkdir v8

# %%
cd /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/v8
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/v8

# %%
# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/yolov8/data.yaml", epochs=50, imgsz=416)  # train the
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 65.6MB/s]
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
p_yol5 = 0.893
r_yol5 = 0.895
mAP_yolo5 = 0.926

storeResults('Yolo v8',p_yol5,r_yol5,mAP_yolo5)

# %% [markdown]
# # **Yolov9**

# %%
cd /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3

# %%
# !mkdir v9

# %%
cd v9
# Out:
# /mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/v9

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov9c.pt")

# Use the model
results = model.train(data="/mnt/c/Users/TruProjects/Desktop/Truprojects/24-25/DL/yolo/3/yolov9/data.yaml", epochs=50, imgsz=416)  # train the model
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 49.4M/49.4M [00:01<00:00, 31.3MB/s]
# Ultralytics 8.3.6 🚀 Python-3.11.7 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
p_yol5 = 0.812
r_yol5 = 0.863
mAP_yolo5 = 0.9

storeResults('Yolo v9',p_yol5,r_yol5,mAP_yolo5)

# %% [markdown]
# # Comparison

# %%
#creating dataframe
import pandas as pd
result = pd.DataFrame({ 'ML Model' : ML_Model,

                       'Precision': precision,
                       'Recall'   : recall,
                       'mAP' : mAP,


                      })

# %%
result
# Out:
#     ML Model  Precision  Recall    mAP
# 0  Yolo v5s6      0.882   0.829  0.924
# 1  Yolo v5x6      0.856   0.819  0.918
# 2    Yolo v8      0.893   0.895  0.926
# 3    Yolo v9      0.812   0.863  0.900

# %% [markdown]
# # Graph

# %%
import numpy as np

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %% [markdown]
# # Precision

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, precision, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Recall

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, recall, align='center', alpha=0.5,color='yellow')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # mAP

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, mAP, align='center', alpha=0.5,color='navy')
plt2.yticks(y_pos, classifier)
plt2.xlabel('mAP')
plt2.title('Classification Performance')
plt2.show()
